# %%
import sys
sys.path.append("../src")

from ejercicio10 import saludar

saludar()
# Out:
# Hola desde src

# %%
print("Jupyter funcionando correctamente")
# Out:
# Jupyter funcionando correctamente
