# %%
import sys
sys.path.append("../src")

# %%
from ejercicio10 import (
    rounds,
    inicializar_estadisticas,
    procesar_ronda,
    mostrar_tabla_progresiva,
    calcular_resultados_finales,
    mostrar_tabla_final,
)

# %%
estadisticas = inicializar_estadisticas(rounds)

for i, ronda in enumerate(rounds, start=1):
    print(f"\nRonda {i} - {ronda['theme']}")
    ganador, puntaje_ganador, _ = procesar_ronda(ronda, estadisticas)
    print(f"Ganador: {ganador} ({puntaje_ganador} pts)")
    mostrar_tabla_progresiva(estadisticas)
# Out:
# Ronda 1 - Entrada
# Ganador: Camila (26 pts)
# Tabla de posiciones (acumulada):
# Camila: 26 pts
# Valentina: 24 pts
# Lucía: 24 pts
# Mateo: 22 pts
# Santiago: 19 pts
#
# Ronda 2 - Plato principal
# Ganador: Valentina (26 pts)
# Tabla de posiciones (acumulada):
# Valentina: 50 pts
# Mateo: 46 pts
# Camila: 46 pts
# Lucía: 46 pts
# Santiago: 44 pts
#
# Ronda 3 - Postre
# Ganador: Lucía (27 pts)
# Tabla de posiciones (acumulada):
# Lucía: 73 pts
# Valentina: 72 pts
# Mateo: 72 pts
# Camila: 70 pts
# Santiago: 64 pts
#
# Ronda 4 - Cocina internacional
# Ganador: Valentina (26 pts)
# Tabla de posiciones (acumulada):
# Valentina: 98 pts
# Camila: 95 pts
# Lucía: 95 pts
# Mateo: 92 pts
# Santiago: 88 pts
#
# Ronda 5 - Final libre
# Ganador: Santiago (27 pts)
# Tabla de posiciones (acumulada):
# Valentina: 124 pts
# Lucía: 118 pts
# Mateo: 117 pts
# Camila: 116 pts
# Santiago: 115 pts

# %%
resultados_finales = calcular_resultados_finales(estadisticas)
mostrar_tabla_final(resultados_finales)
# Out:
# Tabla de posiciones final:
# Cocinero        Puntaje    Rondas ganadas  Mejor ronda  Promedio
# -----------------------------------------------------------------
# Valentina       124        2               26           24.8
# Lucía           118        1               27           23.6
# Mateo           117        0               26           23.4
# Camila          116        1               26           23.2
# Santiago        115        1               27           23.0
